# %% [markdown]
# #                                WeRateDogs Project

# %% [markdown]
# #### Prepared by: Taha Badawy

# %%
#Import all packages needed
import pandas as pd 
import numpy as np
import requests
import tweepy
from matplotlib import pyplot as plt
# %matplotlib inline
import os
import seaborn as sb
import matplotlib
import json 
import PIL.Image
from io import BytesIO
from PIL import Image

# %% [markdown]
# ## A - Data Sources (Gathering Data):
#
# ## All the data used in this project are gathered by 3 ways:

# %% [markdown]
# 1- Twitter archive file it's CSV file downloaded manually from Udacity data resources.
#
# 2- The tweet image predictions it's TSV file downloaded programmatically from the giving link ( URL: https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv ) and it describe the breed of dogs related to the neural network.
#
# 3- Twitter API & JSON: Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count.

# %% [markdown]
# ### 1- Twitter archive file (CSV)

# %%
#read csv file:
df_twt_arch = pd.read_csv('twitter-archive-enhanced.csv')

# %%
df_twt_arch.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
df_twt_arch.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name doggo floofer pupper puppo
# 2351                  10  None  None    None   None  None
# 2352                  10     a  None    None   None  None
# 2353                  10     a  None    None   None  None
# 2354                  10     a  None    None   None  None
# 2355                  10  None  None    None   None  None

# %%
df_twt_arch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# ### 2- Tweet image prediction (TSV):

# %%
#URL downloaded programatically 

url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response = requests.get(url)

with open('image-predictions.tsv', mode ='wb') as file:
    file.write(response.content)

#Read TSV file
df_twt_image = pd.read_csv('image-predictions.tsv', sep='\t' )

# %%
df_twt_image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
df_twt_image.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# 2070    True  German_short-haired_pointer  0.175219    True
# 2071    True                      spatula  0.040836   False
# 2072    True                       kelpie  0.031379    True
# 2073    True                     papillon  0.068957    True
# 2074   False                       banana  0.076110   False

# %%
df_twt_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ## 3- Twitter downloaded API and JSON files:

# %%
#Download data from Twitter API:
if not os.path.exists('tweet-json.txt'):
    get_twitter_data(df_twt_arch, 'tweet-json.txt')

# %%
#load Twitter data in pd:
with open('tweet-json.txt') as file:
    df_API = pd.read_json(file, lines = True, encoding = 'utf-8')

# %%
df_API.head()
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...
# 1  {'media': [{'id': 892177413194625024, 'id_str'...
# 2  {'media': [{'id': 891815175371796480, 'id_str'...
# 3  {'media': [{'id': 891689552724799489, 'id_str'...
# 4  {'media': [{'id': 891327551943041024, 'id_str'...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ...  favorite_count  favorited  retweeted possibly_sensitive  \
# 0  ...           39467      False      False                0.0
# 1  ...           33819      False      False                0.0
# 2  ...           25461      False      False                0.0
# 3  ...           42908      False      False                0.0
# 4  ...           41048      False      False                0.0
#
#   possibly_sensitive_appealable  lang  retweeted_status quoted_status_id  \
# 0                           0.0    en               NaN              NaN
# 1                           0.0    en               NaN              NaN
# 2                           0.0    en               NaN              NaN
# 3                           0.0    en               NaN              NaN
# 4                           0.0    en               NaN              NaN
#
#    quoted_status_id_str  quoted_status
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
#
# [5 rows x 31 columns]

# %%
df_API.tail()
# Out:
#                     created_at                  id              id_str  \
# 2349 2015-11-16 00:24:50+00:00  666049248165822465  666049248165822464
# 2350 2015-11-16 00:04:52+00:00  666044226329800704  666044226329800704
# 2351 2015-11-15 23:21:54+00:00  666033412701032449  666033412701032448
# 2352 2015-11-15 23:05:30+00:00  666029285002620928  666029285002620928
# 2353 2015-11-15 22:32:08+00:00  666020888022790149  666020888022790144
#
#                                               full_text  truncated  \
# 2349  Here we have a 1949 1st generation vulpix. Enj...      False
# 2350  This is a purebred Piers Morgan. Loves to Netf...      False
# 2351  Here is a very happy pup. Big fan of well-main...      False
# 2352  This is a western brown Mitsubishi terrier. Up...      False
# 2353  Here we have a Japanese Irish Setter. Lost eye...      False
#
#      display_text_range                                           entities  \
# 2349           [0, 120]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2350           [0, 137]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2351           [0, 130]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2352           [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2353           [0, 131]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  \
# 2349  {'media': [{'id': 666049244999131136, 'id_str'...
# 2350  {'media': [{'id': 666044217047650304, 'id_str'...
# 2351  {'media': [{'id': 666033409081393153, 'id_str'...
# 2352  {'media': [{'id': 666029276303482880, 'id_str'...
# 2353  {'media': [{'id': 666020881337073664, 'id_str'...
#
#                                                  source  \
# 2349  <a href="http://twitter.com/download/iphone" r...
# 2350  <a href="http://twitter.com/download/iphone" r...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
#
#       in_reply_to_status_id  ...  favorite_count  favorited  retweeted  \
# 2349                    NaN  ...             111      False      False
# 2350                    NaN  ...             311      False      False
# 2351                    NaN  ...             128      False      False
# 2352                    NaN  ...             132      False      False
# 2353                    NaN  ...            2535      False      False
#
#      possibly_sensitive possibly_sensitive_appealable  lang  retweeted_status  \
# 2349                0.0                           0.0    en               NaN
# 2350                0.0                           0.0    en               NaN
# 2351                0.0                           0.0    en               NaN
# 2352                0.0                           0.0    en               NaN
# 2353                0.0                           0.0    en               NaN
#
#      quoted_status_id  quoted_status_id_str  quoted_status
# 2349              NaN                   NaN            NaN
# 2350              NaN                   NaN            NaN
# 2351              NaN                   NaN            NaN
# 2352              NaN                   NaN            NaN
# 2353              NaN                   NaN            NaN
#
# [5 rows x 31 columns]

# %%
df_API.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
#  12  in_reply_to_user_id_str        78 non-null     float64
#  13  in_reply_to_screen_name        78 non-null     object
#  14  user                           2354 non-null   object
#  15  geo                            0 non-null      float64
#  16  coordinates                    0 non-null      float64
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      float64
#  19  is_quote_status                2354 non-null   bool
#  20  retweet_count                  2354 non-null   int64
#  21  favorite_count                 2354 non-null   int64
#  22  favorited                      2354 non-null   bool
#  23  retweeted                      2354 non-null   bool
#  24  possibly_sensitive             2211 non-null   float64
#  25  possibly_sensitive_appealable  2211 non-null   float64
#  26  lang                           2354 non-null   object
#  27  retweeted_status               179 non-null    object
#  28  quoted_status_id               29 non-null     float64
#  29  quoted_status_id_str           29 non-null     float64
#  30  quoted_status                  28 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(11), int64(4), object(11)
# memory usage: 505.9+ KB

# %% [markdown]
# ### B - Assessing Data:

# %% [markdown]
# ### 1- Visual Assessment:

# %%
df_twt_arch
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %%
df_twt_image
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
df_API
# Out:
#                     created_at                  id              id_str  \
# 0    2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1    2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2    2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3    2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4    2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
# ...                        ...                 ...                 ...
# 2349 2015-11-16 00:24:50+00:00  666049248165822465  666049248165822464
# 2350 2015-11-16 00:04:52+00:00  666044226329800704  666044226329800704
# 2351 2015-11-15 23:21:54+00:00  666033412701032449  666033412701032448
# 2352 2015-11-15 23:05:30+00:00  666029285002620928  666029285002620928
# 2353 2015-11-15 22:32:08+00:00  666020888022790149  666020888022790144
#
#                                               full_text  truncated  \
# 0     This is Phineas. He's a mystical boy. Only eve...      False
# 1     This is Tilly. She's just checking pup on you....      False
# 2     This is Archie. He is a rare Norwegian Pouncin...      False
# 3     This is Darla. She commenced a snooze mid meal...      False
# 4     This is Franklin. He would like you to stop ca...      False
# ...                                                 ...        ...
# 2349  Here we have a 1949 1st generation vulpix. Enj...      False
# 2350  This is a purebred Piers Morgan. Loves to Netf...      False
# 2351  Here is a very happy pup. Big fan of well-main...      False
# 2352  This is a western brown Mitsubishi terrier. Up...      False
# 2353  Here we have a Japanese Irish Setter. Lost eye...      False
#
#      display_text_range                                           entities  \
# 0               [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1              [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2              [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3               [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4              [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
# ...                 ...                                                ...
# 2349           [0, 120]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2350           [0, 137]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2351           [0, 130]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2352           [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2353           [0, 131]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  \
# 0     {'media': [{'id': 892420639486877696, 'id_str'...
# 1     {'media': [{'id': 892177413194625024, 'id_str'...
# 2     {'media': [{'id': 891815175371796480, 'id_str'...
# 3     {'media': [{'id': 891689552724799489, 'id_str'...
# 4     {'media': [{'id': 891327551943041024, 'id_str'...
# ...                                                 ...
# 2349  {'media': [{'id': 666049244999131136, 'id_str'...
# 2350  {'media': [{'id': 666044217047650304, 'id_str'...
# 2351  {'media': [{'id': 666033409081393153, 'id_str'...
# 2352  {'media': [{'id': 666029276303482880, 'id_str'...
# 2353  {'media': [{'id': 666020881337073664, 'id_str'...
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2349  <a href="http://twitter.com/download/iphone" r...
# 2350  <a href="http://twitter.com/download/iphone" r...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
#
#       in_reply_to_status_id  ...  favorite_count  favorited  retweeted  \
# 0                       NaN  ...           39467      False      False
# 1                       NaN  ...           33819      False      False
# 2                       NaN  ...           25461      False      False
# 3                       NaN  ...           42908      False      False
# 4                       NaN  ...           41048      False      False
# ...                     ...  ...             ...        ...        ...
# 2349                    NaN  ...             111      False      False
# 2350                    NaN  ...             311      False      False
# 2351                    NaN  ...             128      False      False
# 2352                    NaN  ...             132      False      False
# 2353                    NaN  ...            2535      False      False
#
#      possibly_sensitive possibly_sensitive_appealable  lang  retweeted_status  \
# 0                   0.0                           0.0    en               NaN
# 1                   0.0                           0.0    en               NaN
# 2                   0.0                           0.0    en               NaN
# 3                   0.0                           0.0    en               NaN
# 4                   0.0                           0.0    en               NaN
# ...                 ...                           ...   ...               ...
# 2349                0.0                           0.0    en               NaN
# 2350                0.0                           0.0    en               NaN
# 2351                0.0                           0.0    en               NaN
# 2352                0.0                           0.0    en               NaN
# 2353                0.0                           0.0    en               NaN
#
#      quoted_status_id  quoted_status_id_str  quoted_status
# 0                 NaN                   NaN            NaN
# 1                 NaN                   NaN            NaN
# 2                 NaN                   NaN            NaN
# 3                 NaN                   NaN            NaN
# 4                 NaN                   NaN            NaN
# ...               ...                   ...            ...
# 2349              NaN                   NaN            NaN
# 2350              NaN                   NaN            NaN
# 2351              NaN                   NaN            NaN
# 2352              NaN                   NaN            NaN
# 2353              NaN                   NaN            NaN
#
# [2354 rows x 31 columns]

# %% [markdown]
# ### 2 - Programmatic assessment:

# %%
#check datatype and columns data:
df_twt_arch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
#Check data initial statistics:
df_twt_arch.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
# Check Duplicated tweet ID:
df_twt_arch['tweet_id'].duplicated().sum()
# Out:
# 0

# %%
#Check Columns Details:
df_twt_arch.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
#Check random 5 samples:
df_twt_arch.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1043  743835915802583040                    NaN                  NaN
# 389   826476773533745153                    NaN                  NaN
# 1947  673700254269775872                    NaN                  NaN
# 1668  682638830361513985                    NaN                  NaN
# 1410  699036661657767936                    NaN                  NaN
#
#                       timestamp  \
# 1043  2016-06-17 16:01:16 +0000
# 389   2017-01-31 17:06:32 +0000
# 1947  2015-12-07 03:07:12 +0000
# 1668  2015-12-31 19:05:54 +0000
# 1410  2016-02-15 01:05:02 +0000
#
#                                                  source  \
# 1043  <a href="http://twitter.com/download/iphone" r...
# 389   <a href="http://twitter.com/download/iphone" r...
# 1947  <a href="http://twitter.com/download/iphone" r...
# 1668  <a href="http://twitter.com/download/iphone" r...
# 1410  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1043  RT @dog_rates: Extremely intelligent dog here....         6.671383e+17
# 389   This is Pilot. He has mastered the synchronize...                  NaN
# 1947  Large blue dog here. Cool shades. Flipping us ...                  NaN
# 1668  I have no words. Just a magnificent pup. 12/10...                  NaN
# 1410  HAPPY V-DAY FROM YOUR FAV PUPPER SQUAD 13/10 f...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1043              4.196984e+09  2015-11-19 00:32:12 +0000
# 389                        NaN                        NaN
# 1947                       NaN                        NaN
# 1668                       NaN                        NaN
# 1410                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1043  https://twitter.com/dog_rates/status/667138269...                10
# 389   https://twitter.com/dog_rates/status/826476773...                12
# 1947  https://twitter.com/dog_rates/status/673700254...                 3
# 1668  https://twitter.com/dog_rates/status/682638830...                12
# 1410  https://twitter.com/dog_rates/status/699036661...                13
#
#       rating_denominator   name  doggo floofer  pupper puppo
# 1043                  10   None   None    None    None  None
# 389                   10  Pilot  doggo    None    None  None
# 1947                  10   None   None    None    None  None
# 1668                  10   None   None    None    None  None
# 1410                  10   None   None    None  pupper  None

# %%
#Rating denominator should be 10!!
df_twt_arch.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
#Rating max score should be 10!!
df_twt_arch[df_twt_arch.rating_numerator >= 10].count()
# Out:
# tweet_id                      1916
# in_reply_to_status_id           66
# in_reply_to_user_id             66
# timestamp                     1916
# source                        1916
# text                          1916
# retweeted_status_id            172
# retweeted_status_user_id       172
# retweeted_status_timestamp     172
# expanded_urls                 1867
# rating_numerator              1916
# rating_denominator            1916
# name                          1916
# doggo                         1916
# floofer                       1916
# pupper                        1916
# puppo                         1916
# dtype: int64

# %%
# check inconsistent names like 'a' and 'None'
df_twt_arch['name'].value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Lucy        11
# Oliver      11
#           ...
# Bobb         1
# Emma         1
# Ron          1
# Milky        1
# Rey          1
# Name: name, Length: 957, dtype: int64

# %%
df_twt_arch[df_twt_arch.name == 'None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# 24    2017-07-18 16:08:03 +0000
# 25    2017-07-18 00:07:08 +0000
# ...                         ...
# 2342  2015-11-16 02:38:37 +0000
# 2343  2015-11-16 01:59:36 +0000
# 2344  2015-11-16 01:52:02 +0000
# 2351  2015-11-16 00:24:50 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 5     <a href="http://twitter.com/download/iphone" r...
# 7     <a href="http://twitter.com/download/iphone" r...
# 12    <a href="http://twitter.com/download/iphone" r...
# 24    <a href="http://twitter.com/download/iphone" r...
# 25    <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2342  <a href="http://twitter.com/download/iphone" r...
# 2343  <a href="http://twitter.com/download/iphone" r...
# 2344  <a href="http://twitter.com/download/iphone" r...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 5     Here we have a majestic great white breaching ...                  NaN
# 7     When you watch your owner call another dog a g...                  NaN
# 12    Here's a puppo that seems to be on the fence a...                  NaN
# 24    You may not have known you needed to see this ...                  NaN
# 25    This... is a Jubilant Antarctic House Bear. We...                  NaN
# ...                                                 ...                  ...
# 2342  Here we have a well-established sunblockerspan...                  NaN
# 2343  Let's hope this flight isn't Malaysian (lol). ...                  NaN
# 2344  Here we have a northern speckled Rhododendron....                  NaN
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 5                          NaN                        NaN
# 7                          NaN                        NaN
# 12                         NaN                        NaN
# 24                         NaN                        NaN
# 25                         NaN                        NaN
# ...                        ...                        ...
# 2342                       NaN                        NaN
# 2343                       NaN                        NaN
# 2344                       NaN                        NaN
# 2351                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 5     https://twitter.com/dog_rates/status/891087950...                13
# 7     https://twitter.com/dog_rates/status/890729181...                13
# 12    https://twitter.com/dog_rates/status/889665388...                13
# 24    https://twitter.com/dog_rates/status/887343217...                13
# 25    https://twitter.com/dog_rates/status/887101392...                12
# ...                                                 ...               ...
# 2342  https://twitter.com/dog_rates/status/666082916...                 6
# 2343  https://twitter.com/dog_rates/status/666073100...                10
# 2344  https://twitter.com/dog_rates/status/666071193...                 9
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name doggo floofer pupper  puppo
# 5                     10  None  None    None   None   None
# 7                     10  None  None    None   None   None
# 12                    10  None  None    None   None  puppo
# 24                    10  None  None    None   None   None
# 25                    10  None  None    None   None   None
# ...                  ...   ...   ...     ...    ...    ...
# 2342                  10  None  None    None   None   None
# 2343                  10  None  None    None   None   None
# 2344                  10  None  None    None   None   None
# 2351                  10  None  None    None   None   None
# 2355                  10  None  None    None   None   None
#
# [745 rows x 17 columns]

# %%
#Check How many name start with small letter:
df_twt_arch['name'].str.islower().sum()
# Out:
# 109

# %%
# Check Columns details and dtype of the Columns:
df_twt_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#data intitial Statistics:
df_twt_image.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
#Random 10 samples to check data structures:
df_twt_image.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 1679  813217897535406080  https://pbs.twimg.com/media/C0khWkVXEAI389B.jpg
# 1746  823269594223824897  https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg
# 1092  719551379208073216  https://pbs.twimg.com/media/CfxcKU6W8AE-wEx.jpg
# 677   683481228088049664  https://pbs.twimg.com/media/CXw2jSpWMAAad6V.jpg
# 1071  716439118184652801  https://pbs.twimg.com/media/CfFNk7cWAAA-hND.jpg
# 310   671542985629241344  https://pbs.twimg.com/media/CVHMyHMWwAALYXs.jpg
# 1345  759159934323924993  https://pbs.twimg.com/media/CU1zsMSUAAAS0qW.jpg
# 1828  835574547218894849  https://pbs.twimg.com/media/C5iOnigWcAAU3Ry.jpg
# 1622  803380650405482500  https://pbs.twimg.com/media/CyYub2kWEAEYdaq.jpg
# 1248  747816857231626240  https://pbs.twimg.com/media/CmDHdCoWkAACTB4.jpg
#
#       img_num                         p1   p1_conf  p1_dog  \
# 1679        1                    Samoyed  0.905972    True
# 1746        1                    Samoyed  0.585441    True
# 1092        1                   malamute  0.873233    True
# 677         1                   keeshond  0.508951    True
# 1071        1             Siberian_husky  0.396495    True
# 310         1          Shetland_sheepdog  0.980339    True
# 1345        1              Irish_terrier  0.254856    True
# 1828        1  Staffordshire_bullterrier  0.610655    True
# 1622        1                   bookcase  0.890601   False
# 1248        1                   Pembroke  0.768923    True
#
#                         p2   p2_conf  p2_dog                              p3  \
# 1679            Pomeranian  0.048038    True     West_Highland_white_terrier
# 1746            Pomeranian  0.193654    True                      Arctic_fox
# 1092        Siberian_husky  0.076435    True                      Eskimo_dog
# 677                   chow  0.442016    True                 German_shepherd
# 1071              malamute  0.317053    True                      Eskimo_dog
# 310                 collie  0.006693    True                        papillon
# 1345                briard  0.227716    True     soft-coated_wheaten_terrier
# 1828                muzzle  0.132138   False  American_Staffordshire_terrier
# 1622  entertainment_center  0.019287   False                            file
# 1248             Chihuahua  0.029053    True               Shetland_sheepdog
#
#        p3_conf  p3_dog
# 1679  0.035667    True
# 1746  0.071648   False
# 1092  0.035745    True
# 677   0.013206    True
# 1071  0.273419    True
# 310   0.006157    True
# 1345  0.223263    True
# 1828  0.109544    True
# 1622  0.009490   False
# 1248  0.029035    True

# %%
# Check How many predictions are for dogs and how many are not?

print(df_twt_image.p1_dog.value_counts())
print(df_twt_image.p2_dog.value_counts())
print(df_twt_image.p3_dog.value_counts())
# Out:
# True     1532
# False     543
# Name: p1_dog, dtype: int64
# True     1553
# False     522
# Name: p2_dog, dtype: int64
# True     1499
# False     576
# Name: p3_dog, dtype: int64

# %%
#check duplicated data related to tweet ID:
sum(df_twt_image.tweet_id.duplicated())
# Out:
# 0

# %%
#check duplicated data related to jpg_url:
sum(df_twt_image['jpg_url'].duplicated())
# Out:
# 66

# %%
#Check json file Columns details and dtype of the columns: 
df_API.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
#  12  in_reply_to_user_id_str        78 non-null     float64
#  13  in_reply_to_screen_name        78 non-null     object
#  14  user                           2354 non-null   object
#  15  geo                            0 non-null      float64
#  16  coordinates                    0 non-null      float64
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      float64
#  19  is_quote_status                2354 non-null   bool
#  20  retweet_count                  2354 non-null   int64
#  21  favorite_count                 2354 non-null   int64
#  22  favorited                      2354 non-null   bool
#  23  retweeted                      2354 non-null   bool
#  24  possibly_sensitive             2211 non-null   float64
#  25  possibly_sensitive_appealable  2211 non-null   float64
#  26  lang                           2354 non-null   object
#  27  retweeted_status               179 non-null    object
#  28  quoted_status_id               29 non-null     float64
#  29  quoted_status_id_str           29 non-null     float64
#  30  quoted_status                  28 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(11), int64(4), object(11)
# memory usage: 505.9+ KB

# %%
#Check random 10 samples of the data:
df_API.sample(10)
# Out:
#                     created_at                  id              id_str  \
# 343  2017-02-16 01:04:13+00:00  832032802820481025  832032802820481024
# 1174 2016-04-12 20:50:42+00:00  719991154352222208  719991154352222208
# 1630 2016-01-05 19:42:51+00:00  684460069371654144  684460069371654144
# 1264 2016-03-15 21:24:41+00:00  709852847387627521  709852847387627520
# 438  2017-01-13 17:00:21+00:00  819952236453363712  819952236453363712
# 716  2016-10-05 15:47:27+00:00  783695101801398276  783695101801398272
# 1160 2016-04-23 01:41:59+00:00  723688335806480385  723688335806480384
# 685  2016-10-17 17:32:13+00:00  788070120937619456  788070120937619456
# 229  2017-04-01 01:08:10+00:00  847978865427394560  847978865427394560
# 1235 2016-03-22 16:06:19+00:00  712309440758808576  712309440758808576
#
#                                               full_text  truncated  \
# 343   This is Miguel. He was the only remaining dogg...      False
# 1174  This doggo was initially thrilled when she saw...      False
# 1630  This is Jeph. He's a Western Sagittarius Dookm...      False
# 1264  *lets out a tiny whimper and then collapses* ....      False
# 438   This is Oliver. He has dreams of being a servi...      False
# 716   This is Loomis. He's the leader of the Kenneth...      False
# 1160  This is Reginald. He starts screaming at rando...      False
# 685   RT @dog_rates: This is Bo and Ty. Bo eats pape...      False
# 229   RT @dog_rates: This is Charlie. He fell asleep...      False
# 1235  Reminder that we made our first set of sticker...      False
#
#      display_text_range                                           entities  \
# 343            [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1174           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1630           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1264            [0, 77]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 438            [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 716            [0, 126]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1160            [0, 64]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 685            [0, 108]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 229            [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1235           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  \
# 343   {'media': [{'id': 832032796369645570, 'id_str'...
# 1174  {'media': [{'id': 719991136241082368, 'id_str'...
# 1630  {'media': [{'id': 684460065332445184, 'id_str'...
# 1264  {'media': [{'id': 709852841964396544, 'id_str'...
# 438   {'media': [{'id': 819952225594261509, 'id_str'...
# 716   {'media': [{'id': 783695093576368128, 'id_str'...
# 1160  {'media': [{'id': 723688327916998657, 'id_str'...
# 685   {'media': [{'id': 761004543874392064, 'id_str'...
# 229                                                 NaN
# 1235                                                NaN
#
#                                                  source  \
# 343   <a href="http://twitter.com/download/iphone" r...
# 1174  <a href="http://twitter.com/download/iphone" r...
# 1630  <a href="http://twitter.com/download/iphone" r...
# 1264  <a href="http://twitter.com/download/iphone" r...
# 438   <a href="http://twitter.com/download/iphone" r...
# 716   <a href="http://twitter.com/download/iphone" r...
# 1160  <a href="http://twitter.com/download/iphone" r...
# 685   <a href="http://twitter.com/download/iphone" r...
# 229   <a href="http://twitter.com/download/iphone" r...
# 1235  <a href="http://twitter.com/download/iphone" r...
#
#       in_reply_to_status_id  ...  favorite_count  favorited  retweeted  \
# 343                     NaN  ...           13887      False      False
# 1174                    NaN  ...            5281      False      False
# 1630                    NaN  ...            2169      False      False
# 1264                    NaN  ...            3824      False      False
# 438                     NaN  ...            5927      False      False
# 716                     NaN  ...           11650      False      False
# 1160                    NaN  ...            8435      False      False
# 685                     NaN  ...               0      False      False
# 229                     NaN  ...               0      False      False
# 1235                    NaN  ...             269      False      False
#
#      possibly_sensitive possibly_sensitive_appealable  lang  \
# 343                 0.0                           0.0    en
# 1174                0.0                           0.0    en
# 1630                0.0                           0.0    en
# 1264                0.0                           0.0    en
# 438                 0.0                           0.0    en
# 716                 0.0                           0.0    en
# 1160                0.0                           0.0    en
# 685                 0.0                           0.0    en
# 229                 NaN                           NaN    en
# 1235                0.0                           0.0    en
#
#                                        retweeted_status quoted_status_id  \
# 343                                                 NaN              NaN
# 1174                                                NaN              NaN
# 1630                                                NaN              NaN
# 1264                                                NaN              NaN
# 438                                                 NaN              NaN
# 716                                                 NaN              NaN
# 1160                                                NaN              NaN
# 685   {'created_at': 'Thu Aug 04 01:03:17 +0000 2016...              NaN
# 229   {'created_at': 'Thu Feb 16 23:23:38 +0000 2017...              NaN
# 1235                                                NaN     7.099191e+17
#
#       quoted_status_id_str                                      quoted_status
# 343                    NaN                                                NaN
# 1174                   NaN                                                NaN
# 1630                   NaN                                                NaN
# 1264                   NaN                                                NaN
# 438                    NaN                                                NaN
# 716                    NaN                                                NaN
# 1160                   NaN                                                NaN
# 685                    NaN                                                NaN
# 229                    NaN                                                NaN
# 1235          7.099191e+17  {'created_at': 'Wed Mar 16 01:48:07 +0000 2016...
#
# [10 rows x 31 columns]

# %%
# Check all used languanges:
df_API.lang.value_counts()
# Out:
# en     2336
# und       7
# nl        3
# in        3
# et        1
# tl        1
# ro        1
# es        1
# eu        1
# Name: lang, dtype: int64

# %% [markdown]
# # Assessing points:
#
# ## Tidiness:
#
#
# 1- Convert 'timestamp' column dtype to Year, Month and Day datetime Columns.
#
# 2- Drop 'timestamp' Cloumn.
#
#
# ## Quality:
#
# ### (Twitter_Archive)
#
# 1- Change denominator ratings & numerator ratings str to float.
#
# 2- Adjust mistyping of numerator ratings values >10.
#
# 3- replace all denominator ratings to be 10
#
# 4- Convert all dogs 'name' to be 1st letter capitalized.
#
# 5- Rename columns 'name' to 'dog_name' and 'text' to 'tweets'.
#
# 6- Creat new Dog Stage column for Dogs classification.
#
# 7- Drop 'Doggo', 'Floofer', 'Pupper' and 'Puppo' Columns.
#
# 8- Drop all unuseful data columns for data analysis.
#
#
# ### (image_Prediction)
#
# 9- Drop all duplicated jpg_url.
#
# 10-Drop all non dogs predictions.
#
# ### (Tweet_json)
#
# 11 - Drop all unuseful Columns for data analysis.
#
# 12- Rename id to tweet_id to be consistent with others files during merging.
#
# 13- keep only English language tweets
#
#
# ## Tidiness:
#
# 3- Combine all 3 different files to master data set.

# %% [markdown]
# =======================================================================

# %% [markdown]
# # C - Cleaning Data :

# %%
# Copy data from all files:
twt_arch_clean = df_twt_arch.copy()
twt_image_clean = df_twt_image.copy()
API_clean = df_API.copy()

# %% [markdown]
# ## Tidness:

# %% [markdown]
# Covert 'timestamp' to datetime.

# %% [markdown]
# ## Code:

# %%
twt_arch_clean['timestamp'] = pd.to_datetime(twt_arch_clean['timestamp'])

#create new  year, month and day columns:
twt_arch_clean['year'] = twt_arch_clean['timestamp'].dt.year
twt_arch_clean['month'] = twt_arch_clean['timestamp'].dt.month
twt_arch_clean['weekday'] =twt_arch_clean['timestamp'].dt.day_name()

# %% [markdown]
# ## Test:

# %%
twt_arch_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo  year  month  \
# 0                  10   Phineas  None    None   None  None  2017      8
# 1                  10     Tilly  None    None   None  None  2017      8
# 2                  10    Archie  None    None   None  None  2017      7
# 3                  10     Darla  None    None   None  None  2017      7
# 4                  10  Franklin  None    None   None  None  2017      7
#
#     weekday
# 0   Tuesday
# 1   Tuesday
# 2    Monday
# 3    Sunday
# 4  Saturday

# %% [markdown]
# ## Define:

# %% [markdown]
# drop 'timestamp' cloumn

# %% [markdown]
# ## Code:

# %%
# drop 'timestamp' cloumn:
twt_arch_clean = twt_arch_clean.drop(['timestamp'], axis=1)

# %% [markdown]
# ## Test:

# %%
twt_arch_clean.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo  year  month  \
# 0                  10   Phineas  None    None   None  None  2017      8
# 1                  10     Tilly  None    None   None  None  2017      8
# 2                  10    Archie  None    None   None  None  2017      7
# 3                  10     Darla  None    None   None  None  2017      7
# 4                  10  Franklin  None    None   None  None  2017      7
#
#     weekday
# 0   Tuesday
# 1   Tuesday
# 2    Monday
# 3    Sunday
# 4  Saturday

# %% [markdown]
# # Quality:

# %% [markdown]
# ## (Tweeter_archive)

# %% [markdown]
# ## Define:

# %% [markdown]
# Change numerator & denominator rating type to float.

# %% [markdown]
# ## Code:

# %%
twt_arch_clean[['rating_numerator', 'rating_denominator']] = twt_arch_clean[['rating_numerator','rating_denominator']].astype(float)

# %% [markdown]
# ## Test:

# %%
twt_arch_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   source                      2356 non-null   object
#  4   text                        2356 non-null   object
#  5   retweeted_status_id         181 non-null    float64
#  6   retweeted_status_user_id    181 non-null    float64
#  7   retweeted_status_timestamp  181 non-null    object
#  8   expanded_urls               2297 non-null   object
#  9   rating_numerator            2356 non-null   float64
#  10  rating_denominator          2356 non-null   float64
#  11  name                        2356 non-null   object
#  12  doggo                       2356 non-null   object
#  13  floofer                     2356 non-null   object
#  14  pupper                      2356 non-null   object
#  15  puppo                       2356 non-null   object
#  16  year                        2356 non-null   int64
#  17  month                       2356 non-null   int64
#  18  weekday                     2356 non-null   object
# dtypes: float64(6), int64(3), object(10)
# memory usage: 349.8+ KB

# %% [markdown]
# ## Define:

# %% [markdown]
# Adjust mistyping of numerator ratings values >= 20.

# %% [markdown]
# ## Code:

# %%
for i in range(1,len(twt_arch_clean.rating_numerator),1):
    if twt_arch_clean.rating_numerator.iloc[i]<=20:
        continue
    elif twt_arch_clean.rating_numerator.iloc[i] > 20 and twt_arch_clean.rating_numerator.iloc[i]<=200:
        twt_arch_clean.rating_numerator.iloc[i] = twt_arch_clean.rating_numerator.iloc[i]*0.1 
    elif twt_arch_clean.rating_numerator.iloc[i]>200: 
        twt_arch_clean.rating_numerator.iloc[i] = twt_arch_clean.rating_numerator.iloc[i]*0.01
# Out:
# C:\Users\b\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %% [markdown]
# ## Test:

# %%
twt_arch_clean.rating_numerator.value_counts()
# Out:
# 12.00    558
# 11.00    464
# 10.00    461
# 13.00    351
# 9.00     158
# 8.00     103
# 7.00      55
# 14.00     54
# 5.00      38
# 6.00      33
# 3.00      19
# 4.00      17
# 1.00       9
# 2.00       9
# 7.50       2
# 0.00       2
# 4.20       2
# 15.00      2
# 17.00      1
# 8.40       1
# 4.50       1
# 16.50      1
# 12.10      1
# 9.90       1
# 17.76      1
# 2.40       1
# 2.60       1
# 14.30      1
# 14.40      1
# 4.40       1
# 9.60       1
# 2.70       1
# 8.80       1
# 18.20      1
# 6.66       1
# 2.04       1
# 20.00      1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# ## Define:

# %% [markdown]
# Standerdize denominator ratings to be 10.

# %% [markdown]
# ## Code:

# %%
twt_arch_clean['rating_denominator'] = 10.0

# %% [markdown]
# ## Test:

# %%
twt_arch_clean['rating_denominator'].value_counts()
# Out:
# 10.0    2356
# Name: rating_denominator, dtype: int64

# %% [markdown]
# ## Define:

# %% [markdown]
# Capitalize 1st letter in Dogs name column:

# %% [markdown]
# ## Code:

# %%
twt_arch_clean['name'] = twt_arch_clean['name'].str.title()

# %% [markdown]
# ## Test:

# %%
twt_arch_clean['name']
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
#           ...
# 2351        None
# 2352           A
# 2353           A
# 2354           A
# 2355        None
# Name: name, Length: 2356, dtype: object

# %% [markdown]
# ## Define:

# %% [markdown]
# Rename name & text to be more constent.

# %% [markdown]
# ## Code:

# %%
twt_arch_clean = twt_arch_clean.rename(columns={'text':'tweets', 'name':'dog_name' })

# %% [markdown]
# ## Test:

# %%
list(twt_arch_clean)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'source',
#  'tweets',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'dog_name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo',
#  'year',
#  'month',
#  'weekday']

# %% [markdown]
# ## Define:

# %% [markdown]
# Create dog_stage to combine 4 calssifications of dogs and drop old columns:

# %% [markdown]
# ## Code:

# %%
#use for loop to create the stage:
stage = ['doggo','pupper', 'floofer', 'puppo' ]
for x in stage:
       twt_arch_clean[x] = twt_arch_clean[x].replace('None', '')

# %%
# combine all cloumns in dog_stage column:
twt_arch_clean['dog_stage'] = twt_arch_clean.doggo.str.cat(twt_arch_clean.floofer).str.cat(twt_arch_clean.pupper).str.cat(twt_arch_clean.puppo)

# %%
# drop the four old colomns
twt_arch_clean = twt_arch_clean.drop(['doggo','floofer','pupper','puppo'], axis = 1)

# %%
# fill empty spaces by NaN:
twt_arch_clean['dog_stage'] = twt_arch_clean['dog_stage'].replace('', np.nan)

# %% [markdown]
# ## Test:

# %%
twt_arch_clean.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1927  674051556661161984                    NaN                  NaN
# 589   799308762079035393                    NaN                  NaN
# 136   866334964761202691                    NaN                  NaN
# 1117  732375214819057664                    NaN                  NaN
# 1271  709409458133323776                    NaN                  NaN
#
#                                                  source  \
# 1927  <a href="http://twitter.com/download/iphone" r...
# 589   <a href="http://twitter.com/download/iphone" r...
# 136   <a href="http://twitter.com/download/iphone" r...
# 1117  <a href="http://twitter.com/download/iphone" r...
# 1271  <a href="http://twitter.com/download/iphone" r...
#
#                                                  tweets  retweeted_status_id  \
# 1927  This is Lucy. She knits. Specializes in tobogg...                  NaN
# 589   RT @dog_rates: I WAS SENT THE ACTUAL DOG IN TH...         7.743144e+17
# 136   This is Coco. At first I thought she was a clo...                  NaN
# 1117  This is Kyle (pronounced 'Mitch'). He strives ...                  NaN
# 1271  This is Billy. He sensed a squirrel. 8/10 damn...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1927                       NaN                        NaN
# 589               4.196984e+09  2016-09-09 18:31:54 +0000
# 136                        NaN                        NaN
# 1117                       NaN                        NaN
# 1271                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1927  https://twitter.com/dog_rates/status/674051556...              10.0
# 589   https://twitter.com/dog_rates/status/774314403...              14.0
# 136   https://twitter.com/dog_rates/status/866334964...              12.0
# 1117  https://twitter.com/dog_rates/status/732375214...              11.0
# 1271  https://twitter.com/dog_rates/status/709409458...               8.0
#
#       rating_denominator dog_name  year  month   weekday dog_stage
# 1927                10.0     Lucy  2015     12   Tuesday       NaN
# 589                 10.0     None  2016     11  Thursday       NaN
# 136                 10.0     Coco  2017      5    Sunday       NaN
# 1117                10.0     Kyle  2016      5   Tuesday     doggo
# 1271                10.0    Billy  2016      3    Monday       NaN

# %% [markdown]
# ## Define:

# %% [markdown]
# Drop all unused columns in the analysis:

# %% [markdown]
# ## Code:

# %%
twt_arch_clean=twt_arch_clean.drop(['retweeted_status_id','in_reply_to_status_id','in_reply_to_user_id',
 'retweeted_status_user_id',
 'retweeted_status_timestamp',
 'expanded_urls','source'], axis = 1)

# %%
twt_arch_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   tweets              2356 non-null   object
#  2   rating_numerator    2356 non-null   float64
#  3   rating_denominator  2356 non-null   float64
#  4   dog_name            2356 non-null   object
#  5   year                2356 non-null   int64
#  6   month               2356 non-null   int64
#  7   weekday             2356 non-null   object
#  8   dog_stage           380 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 165.8+ KB

# %% [markdown]
# ## (Image_prediction)

# %% [markdown]
# ## Define:

# %% [markdown]
# Drop duplicates of jpg_url coulmn:

# %% [markdown]
# ## Code:

# %%
twt_image_clean = twt_image_clean.drop_duplicates(subset=['jpg_url'], keep='first')

# %% [markdown]
# ## Test:

# %%
sum(twt_image_clean['jpg_url'].duplicated())
# Out:
# 0

# %% [markdown]
# ## Define:

# %% [markdown]
# Drop all non dogs preidiction:

# %% [markdown]
# ## Code:

# %%
#create new lists for dog type and conf. list:
dog_type = []
confidence_list = []

#from the function and nested if to fill the new lists with true values of function:
# from the first 'true' prediction
def image(twt_image_clean):
    if twt_image_clean['p1_dog'] == True:
        dog_type.append(twt_image_clean['p1'])
        confidence_list.append(twt_image_clean['p1_conf'])
    elif twt_image_clean['p2_dog'] == True:
        dog_type.append(twt_image_clean['p2'])
        confidence_list.append(twt_image_clean['p2_conf'])
    elif twt_image_clean['p3_dog'] == True:
        dog_type.append(twt_image_clean['p3'])
        confidence_list.append(twt_image_clean['p3_conf'])
    else:
        dog_type.append('Error')
        confidence_list.append('Error')

#series objects having index the image_prediction_clean column.        
twt_image_clean.apply(image, axis=1)

#create new columns
twt_image_clean['dog_type'] = dog_type
twt_image_clean['confidence_list'] = confidence_list

# %% [markdown]
# ## Test:

# %%
twt_image_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2009 entries, 0 to 2074
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         2009 non-null   int64
#  1   jpg_url          2009 non-null   object
#  2   img_num          2009 non-null   int64
#  3   p1               2009 non-null   object
#  4   p1_conf          2009 non-null   float64
#  5   p1_dog           2009 non-null   bool
#  6   p2               2009 non-null   object
#  7   p2_conf          2009 non-null   float64
#  8   p2_dog           2009 non-null   bool
#  9   p3               2009 non-null   object
#  10  p3_conf          2009 non-null   float64
#  11  p3_dog           2009 non-null   bool
#  12  dog_type         2009 non-null   object
#  13  confidence_list  2009 non-null   object
# dtypes: bool(3), float64(3), int64(2), object(6)
# memory usage: 194.2+ KB

# %% [markdown]
# ## Define:

# %% [markdown]
# Drop all rows is not for dogs

# %% [markdown]
# ## Code:

# %%
# drop all rows is not for dogs:
twt_image_clean = twt_image_clean[twt_image_clean['dog_type'] != 'Error']

# %% [markdown]
# ## Test:

# %%
twt_image_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1691 entries, 0 to 2073
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         1691 non-null   int64
#  1   jpg_url          1691 non-null   object
#  2   img_num          1691 non-null   int64
#  3   p1               1691 non-null   object
#  4   p1_conf          1691 non-null   float64
#  5   p1_dog           1691 non-null   bool
#  6   p2               1691 non-null   object
#  7   p2_conf          1691 non-null   float64
#  8   p2_dog           1691 non-null   bool
#  9   p3               1691 non-null   object
#  10  p3_conf          1691 non-null   float64
#  11  p3_dog           1691 non-null   bool
#  12  dog_type         1691 non-null   object
#  13  confidence_list  1691 non-null   object
# dtypes: bool(3), float64(3), int64(2), object(6)
# memory usage: 163.5+ KB

# %% [markdown]
# ## Define:

# %% [markdown]
# Drop useless column in the analysis:

# %% [markdown]
# ## Code:

# %%
twt_image_clean = twt_image_clean.drop(['img_num', 'p1', 
                                                      'p1_conf', 'p1_dog', 
                                                      'p2', 'p2_conf', 
                                                      'p2_dog', 'p3', 
                                                      'p3_conf', 
                                                      'p3_dog'], 1)

# %% [markdown]
# ## Test:

# %%
twt_image_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1691 entries, 0 to 2073
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         1691 non-null   int64
#  1   jpg_url          1691 non-null   object
#  2   dog_type         1691 non-null   object
#  3   confidence_list  1691 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 66.1+ KB

# %% [markdown]
# # (Tweet_json)

# %% [markdown]
# ## Define:

# %% [markdown]
# Rename id column to be tweet_id for consistancy with other files:

# %% [markdown]
# ## Code:

# %%
API_clean = API_clean.rename(columns={'id':'tweet_id'})

# %% [markdown]
# ## Test:

# %%
API_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   tweet_id                       2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
#  12  in_reply_to_user_id_str        78 non-null     float64
#  13  in_reply_to_screen_name        78 non-null     object
#  14  user                           2354 non-null   object
#  15  geo                            0 non-null      float64
#  16  coordinates                    0 non-null      float64
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      float64
#  19  is_quote_status                2354 non-null   bool
#  20  retweet_count                  2354 non-null   int64
#  21  favorite_count                 2354 non-null   int64
#  22  favorited                      2354 non-null   bool
#  23  retweeted                      2354 non-null   bool
#  24  possibly_sensitive             2211 non-null   float64
#  25  possibly_sensitive_appealable  2211 non-null   float64
#  26  lang                           2354 non-null   object
#  27  retweeted_status               179 non-null    object
#  28  quoted_status_id               29 non-null     float64
#  29  quoted_status_id_str           29 non-null     float64
#  30  quoted_status                  28 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(11), int64(4), object(11)
# memory usage: 505.9+ KB

# %% [markdown]
# ## Define:

# %% [markdown]
#  Drop rows of other languages than English:

# %%
API_clean.lang.value_counts()
# Out:
# en     2336
# und       7
# nl        3
# in        3
# et        1
# tl        1
# ro        1
# es        1
# eu        1
# Name: lang, dtype: int64

# %% [markdown]
# ## Code:

# %%
API_clean = API_clean[API_clean.lang == 'en']

# %% [markdown]
# ## Test:

# %%
API_clean.lang.value_counts()
# Out:
# en    2336
# Name: lang, dtype: int64

# %% [markdown]
# ## Define:

# %% [markdown]
# Drop all unusefull columns for analysis:

# %% [markdown]
# ## Code:

# %%
API_clean=API_clean.drop(['created_at','full_text','geo','truncated','favorited','display_text_range','retweeted_status','retweeted','coordinates','place',
 'contributors','in_reply_to_status_id',
 'in_reply_to_status_id_str','id_str',
 'in_reply_to_user_id',
 'in_reply_to_user_id_str',
 'in_reply_to_screen_name','quoted_status_id',
 'quoted_status_id_str',
 'quoted_status','source','display_text_range','is_quote_status','entities','extended_entities','user','possibly_sensitive','possibly_sensitive_appealable'],axis=1)

# %% [markdown]
# ## Test:

# %%
list(API_clean)
# Out:
# ['tweet_id', 'retweet_count', 'favorite_count', 'lang']

# %%
API_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2336 entries, 0 to 2353
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2336 non-null   int64
#  1   retweet_count   2336 non-null   int64
#  2   favorite_count  2336 non-null   int64
#  3   lang            2336 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 91.2+ KB

# %% [markdown]
# # Tidness:

# %% [markdown]
# ## Define:

# %% [markdown]
# Merge all cleaned files to form one master data set:

# %% [markdown]
# ## Code:

# %%
# Merge cleaned archive file with tweet json file:
twt_merge=pd.merge(twt_arch_clean, API_clean, how='inner', on=None, left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
twt_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2336 entries, 0 to 2335
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2336 non-null   int64
#  1   tweets              2336 non-null   object
#  2   rating_numerator    2336 non-null   float64
#  3   rating_denominator  2336 non-null   float64
#  4   dog_name            2336 non-null   object
#  5   year                2336 non-null   int64
#  6   month               2336 non-null   int64
#  7   weekday             2336 non-null   object
#  8   dog_stage           379 non-null    object
#  9   retweet_count       2336 non-null   int64
#  10  favorite_count      2336 non-null   int64
#  11  lang                2336 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 237.2+ KB

# %%
# Merge twt_megre file with twt_image_clean file:
Twitter_Cleaned=pd.merge(twt_merge, twt_image_clean, how='inner', on=None, left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %% [markdown]
# ## Test:

# %%
Twitter_Cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1686 entries, 0 to 1685
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1686 non-null   int64
#  1   tweets              1686 non-null   object
#  2   rating_numerator    1686 non-null   float64
#  3   rating_denominator  1686 non-null   float64
#  4   dog_name            1686 non-null   object
#  5   year                1686 non-null   int64
#  6   month               1686 non-null   int64
#  7   weekday             1686 non-null   object
#  8   dog_stage           261 non-null    object
#  9   retweet_count       1686 non-null   int64
#  10  favorite_count      1686 non-null   int64
#  11  lang                1686 non-null   object
#  12  jpg_url             1686 non-null   object
#  13  dog_type            1686 non-null   object
#  14  confidence_list     1686 non-null   object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 210.8+ KB

# %%
Twitter_Cleaned.sample(10)
# Out:
#                 tweet_id                                             tweets  \
# 134   669006782128353280  This is Tucker. He is 100% ready for the sport...
# 1454  831670449226514432  This is Daisy. She has a heart on her butt. 13...
# 631   692142790915014657  These are some pictures of Teddy that further ...
# 399   676588346097852417  This is Bubbles. He kinda resembles a fish. Al...
# 994   744709971296780288  This is Harvey. He's stealthy af. 10/10 would ...
# 1143  770293558247038976  This is Jackson. There's nothing abnormal abou...
# 822   710588934686908417  This is Beemo. He's a Chubberflop mix. 12/10 w...
# 1196  780459368902959104  This is Bear. Don't worry, he's not a real bea...
# 623   691321916024623104  This is Molly. She's a Peruvian Niddlewog. Lov...
# 1065  753375668877008896  This is Hank. He's mischievous af. Doesn't eve...
#
#       rating_numerator  rating_denominator dog_name  year  month    weekday  \
# 134               12.0                10.0   Tucker  2015     11    Tuesday
# 1454              13.0                10.0    Daisy  2017      2  Wednesday
# 631               13.0                10.0     None  2016      1  Wednesday
# 399                5.0                10.0  Bubbles  2015     12    Tuesday
# 994               10.0                10.0   Harvey  2016      6     Monday
# 1143              10.0                10.0  Jackson  2016      8     Monday
# 822               12.0                10.0    Beemo  2016      3   Thursday
# 1196              11.0                10.0     Bear  2016      9     Monday
# 623               11.0                10.0    Molly  2016      1     Sunday
# 1065               8.0                10.0     Hank  2016      7  Wednesday
#
#      dog_stage  retweet_count  favorite_count lang  \
# 134        NaN            269             610   en
# 1454       NaN           2059           11469   en
# 631        NaN            438            1798   en
# 399        NaN            896            2533   en
# 994        NaN           1771            6150   en
# 1143       NaN           1718            6923   en
# 822        NaN           2107            4968   en
# 1196       NaN           1224            5892   en
# 623        NaN            747            2828   en
# 1065       NaN           2655            8411   en
#
#                                               jpg_url           dog_type  \
# 134   https://pbs.twimg.com/media/CUjKHs0WIAECWP3.jpg          Chihuahua
# 1454  https://pbs.twimg.com/media/C4qv3JUW8AADirb.jpg           Pembroke
# 631   https://pbs.twimg.com/media/CZr8LvyXEAABJ9k.jpg         toy_poodle
# 399   https://pbs.twimg.com/media/CWO5gmCUYAAX4WA.jpg        Boston_bull
# 994   https://pbs.twimg.com/media/ClW9w7mWEAEFN1k.jpg  Shetland_sheepdog
# 1143  https://pbs.twimg.com/media/CrCh5RgW8AAXW4U.jpg  Italian_greyhound
# 822   https://pbs.twimg.com/media/CdyE2x1W8AAe0TG.jpg           Pembroke
# 1196  https://pbs.twimg.com/media/CtS_p9kXEAE2nh8.jpg         Great_Dane
# 623   https://pbs.twimg.com/media/CZgRmk0UcAAxeuQ.jpg         Rottweiler
# 1065  https://pbs.twimg.com/media/CnSHLFeWgAAwV-I.jpg           bluetick
#
#      confidence_list
# 134         0.127178
# 1454        0.624802
# 631         0.670068
# 399         0.976577
# 994         0.234431
# 1143        0.931668
# 822         0.982004
# 1196        0.382491
# 623         0.508981
# 1065        0.360071

# %% [markdown]
# # Sorting Data:

# %%
# Save cleaned data in new CSV file:
Twitter_Cleaned.to_csv('twitter_archive_master.csv',index=False, encoding = 'utf-8')

# %% [markdown]
# # Visualization Data:

# %%
df_master = pd.read_csv('twitter_archive_master.csv')

# %%
#Check most popular dog type:
df_master['dog_type'].value_counts()
# Out:
# golden_retriever      157
# Labrador_retriever    107
# Pembroke               95
# Chihuahua              91
# pug                    63
#                      ...
# Scotch_terrier          1
# Japanese_spaniel        1
# standard_schnauzer      1
# Irish_wolfhound         1
# clumber                 1
# Name: dog_type, Length: 113, dtype: int64

# %%
dog_type = df_master.groupby('dog_type').filter(lambda x: len(x) >= 20)

dog_type['dog_type'].value_counts().plot(kind = 'bar', figsize = (15, 8))
plt.title('Most popular rated Dogs', fontsize = 15)
plt.xlabel('Dog Type', fontsize = 15)
plt.ylabel('Counts', fontsize = 15)
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ### The most popular Dog type is 'Golden retriever'

# %%
df_master[df_master['dog_type'] == 'golden_retriever']
# Out:
#                 tweet_id                                             tweets  \
# 7     666057090499244032  My oh my. This is a rare blond Canadian terrie...
# 9     666063827256086533  This is the happiest dog you will ever see. Ve...
# 19    666345417576210432  Look at this jokester thinking seat belt laws ...
# 44    667044094246576128            12/10 gimme now https://t.co/QZAnwgnOMB
# 51    667160273090932737  This is Bradlay. He is a Ronaldinho Matsuyama ...
# ...                  ...                                                ...
# 1647  883117836046086144  Please only send dogs. We don't rate mechanics...
# 1649  883482846933004288  This is Bella. She hopes her smile made you sm...
# 1669  888804989199671297  This is Zeke. He has a new stick. Very proud o...
# 1670  888917238123831296  This is Jim. He found a fren. Taught him how t...
# 1672  889531135344209921  This is Stuart. He's sporting his favorite fan...
#
#       rating_numerator  rating_denominator dog_name  year  month    weekday  \
# 7                  9.0                10.0        A  2015     11     Monday
# 9                 10.0                10.0      The  2015     11     Monday
# 19                10.0                10.0     None  2015     11     Monday
# 44                12.0                10.0     None  2015     11  Wednesday
# 51                11.0                10.0  Bradlay  2015     11   Thursday
# ...                ...                 ...      ...   ...    ...        ...
# 1647              13.0                10.0     None  2017      7     Friday
# 1649               5.0                10.0    Bella  2017      7   Saturday
# 1669              13.0                10.0     Zeke  2017      7   Saturday
# 1670              12.0                10.0      Jim  2017      7     Sunday
# 1672              13.0                10.0   Stuart  2017      7     Monday
#
#      dog_stage  retweet_count  favorite_count lang  \
# 7          NaN            146             304   en
# 9          NaN            232             496   en
# 19         NaN            146             307   en
# 44         NaN             54             198   en
# 51         NaN             66             268   en
# ...        ...            ...             ...  ...
# 1647       NaN           6949           37914   en
# 1649       NaN          10407           46860   en
# 1669       NaN           4559           26080   en
# 1670       NaN           4709           29611   en
# 1672     puppo           2321           15359   en
#
#                                               jpg_url          dog_type  \
# 7     https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg  golden_retriever
# 9     https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg  golden_retriever
# 19    https://pbs.twimg.com/media/CT9Vn7PWoAA_ZCM.jpg  golden_retriever
# 44    https://pbs.twimg.com/media/CUHREBXXAAE6A9b.jpg  golden_retriever
# 51    https://pbs.twimg.com/media/CUI6uuaW4AAvCIs.jpg  golden_retriever
# ...                                               ...               ...
# 1647  https://pbs.twimg.com/media/DEF2-_hXoAAs62q.jpg  golden_retriever
# 1649  https://pbs.twimg.com/media/DELC9dZXUAADqUk.jpg  golden_retriever
# 1669  https://pbs.twimg.com/media/DFWra-3VYAA2piG.jpg  golden_retriever
# 1670  https://pbs.twimg.com/media/DFYRgsOUQAARGhO.jpg  golden_retriever
# 1672  https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg  golden_retriever
#
#       confidence_list
# 7            0.007959
# 9            0.775930
# 19           0.858744
# 44           0.765266
# 51           0.471351
# ...               ...
# 1647         0.949562
# 1649         0.943082
# 1669         0.469760
# 1670         0.714719
# 1672         0.953442
#
# [157 rows x 15 columns]

# %%
# some pics for Golden retriver.#highest Dogs Stage according to total rate visitors
master_clean.groupby("dog_stage")['rating_numerator'].sum().plot(kind='bar');
url = df_master.jpg_url[1669]
r = requests.get(url)
Image.open(BytesIO(r.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=901x1200 at 0x58034C0>

# %%
# pic for Golden retriver.
url = df_master.jpg_url[9]
r = requests.get(url)
Image.open(BytesIO(r.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x853 at 0x5803E20>

# %%
df_master['dog_stage'].value_counts()
# Out:
# pupper          169
# doggo            54
# puppo            21
# doggopupper       8
# floofer           7
# doggofloofer      1
# doggopuppo        1
# Name: dog_stage, dtype: int64

# %%
df_master['dog_stage'].value_counts().plot(kind = 'bar', figsize = (15, 8))
plt.title('Most popular dog stage', fontsize = 15)
plt.xlabel('Dog stage', fontsize = 15)
plt.ylabel('Counts', fontsize = 15)
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ### The Most popular dog stage according to Counts is Pupper

# %%
df_master.plot(x='retweet_count', y='rating_numerator', kind='scatter', figsize = (12, 6))
plt.xlabel('Retweet Counts')
plt.ylabel('Ratings')
plt.title('Retweet Counts by Ratings')
# Out:
# Text(0.5, 1.0, 'Retweet Counts by Ratings')

# %% [markdown]
# ### The highst ratings didn't get the most of the retweets

# %%
# Dogs Stage according to total rate. 
df_master.groupby("dog_stage")['rating_numerator'].sum().plot(kind='bar', figsize = (12, 6));

# %% [markdown]
# ## The highst Dog stage according to rating score is Pupper

# %%
## retweet count over time with favorite counts
df_master.plot(y='retweet_count',x='favorite_count',style='s',alpha=0.9,figsize=(12,9),ylim=[10,50000]);

# %% [markdown]
# ### Retweet count over time with favorite counts.

# %% [markdown]
# ### and finally this one is really very cute :)

# %%
url = df_master.jpg_url[169]
r = requests.get(url)
Image.open(BytesIO(r.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=570x938 at 0x16488A60>
